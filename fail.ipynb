# %%
import os
print("Put the .tif files in this exact folder:")
print(os.getcwd())
# Out:
# Put the .tif files in this exact folder:
# /home/ggianforte/Capstone Project

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load the giant map of all US Counties
counties = gpd.read_file("tl_2023_us_county.shp")

# 2. Filter the map to ONLY show Miami-Dade County in Florida (Florida's state code is 12)
miami = counties[(counties['NAME'] == 'Miami-Dade') & (counties['STATEFP'] == '12')]

# 3. Draw a quick plot of the county to make sure it worked
miami.plot()
plt.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load the giant map of all US Counties
counties = gpd.read_file("tl_2023_us_county.shp")

# 2. Filter the map to ONLY show Miami-Dade County in Florida (Florida's state code is 12)
miami = counties[(counties['NAME'] == 'Miami-Dade') & (counties['STATEFP'] == '12')]

# 3. Draw a quick plot of the county to make sure it worked
miami.plot()
plt.show()

# %%
# 1. Load the specific 1-foot sea level rise layer from the GeoPackage
slr_data = gpd.read_file("FL_SE_slr_final_dist.gpkg", layer="FL_SE_slr_1_0ft")

# 2. Make sure the map coordinates match perfectly so they actually line up
if slr_data.crs != miami.crs:
    slr_data = slr_data.to_crs(miami.crs)

# 3. Use CLIP instead of overlay (this is 100x faster for cookie-cutting)
miami_flood = gpd.clip(slr_data, miami)

# 4. Plot them together!
fig, ax = plt.subplots(figsize=(10, 10))
miami.plot(ax=ax, color='lightgrey', edgecolor='black')
miami_flood.plot(ax=ax, color='blue', alpha=0.5) 
plt.show()

# %%
# %pip install rasterio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import glob

# 1. Find all 8 of your .tif files in your Capstone Project folder
tif_files = glob.glob("*.tif")

# 2. Open all of them so Python can read the data
src_files_to_mosaic = []
for fp in tif_files:
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

# 3. Stitch them together into one giant map
mosaic, out_trans = merge(src_files_to_mosaic)

# 4. Save this new stitched map to your folder so you only ever have to do this once
out_meta = src.meta.copy()
out_meta.update({
    "driver": "GTiff",
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": out_trans
})

with rasterio.open("miami_merged_elevation.tif", "w", **out_meta) as dest:
    dest.write(mosaic)

# 5. Plot the final stitched map on the screen to verify it worked
show(mosaic, cmap='terrain')
# Out:
# <AxesSubplot: >

# %%
import numpy as np
from rasterio.plot import show

# 1. Hide the fake -9999 "No Data" numbers by turning them into NaNs (Not a Number)
plot_data = np.where(mosaic < -100, np.nan, mosaic)

# 2. Plot it again, telling Python to only look at realistic elevations (0 to 15 meters)
show(plot_data, cmap='terrain', vmin=0, vmax=15)
# Out:
# <AxesSubplot: >

# %%
import rasterio
from rasterio.merge import merge
from rasterio.mask import mask
import glob

# 1. Find all the downloaded USGS tif files in the folder
tif_files = glob.glob("*.tif") + glob.glob("*.TIF")
# Exclude any old corrupted merged files
tif_files = [f for f in tif_files if "merged" not in f.lower()]

# 2. Open all of the chunks to stitch them together
src_files_to_mosaic = []
for fp in tif_files:
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

# 3. Stitch them together (this safely preserves the spatial data)
mosaic, out_trans = merge(src_files_to_mosaic)

# Grab the metadata from the first file to copy the CRS
out_meta = src_files_to_mosaic[0].meta.copy()

# Update the metadata with the new, larger merged dimensions
out_meta.update({
    "driver": "GTiff",
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": out_trans
})

# Save the properly stitched map
with rasterio.open("miami_merged_elevation_FIXED.tif", "w", **out_meta) as dest:
    dest.write(mosaic)

# Close all the individual chunks
for src in src_files_to_mosaic:
    src.close()

# 4. Now open the FIXED merged map and clip it
with rasterio.open("miami_merged_elevation_FIXED.tif") as src:
    # Re-project the miami vector to match the exact CRS of the raster
    miami_projected = miami.to_crs(src.crs)
    
    # Use the re-projected 'miami' shape to clip the raster
    out_image, out_transform = mask(src, miami_projected.geometry, crop=True)
    out_meta = src.meta.copy()

# 5. Filter the elevation!
# If the elevation is greater than 3 meters (~10 feet), label it '1' (Safe).
# If it is lower than 3 meters, label it '0' (Unsafe).

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- MISSING STEP: Define safe_elevation ---
# If the elevation is greater than 3 meters (~10 feet), label it '1' (Safe).
# If it is lower than 3 meters, label it '0' (Unsafe).
safe_elevation = np.where(out_image > 3, 1, 0)

# 1. Calculate the slope to find how steep the ground is
# np.gradient looks at the elevation difference between neighboring pixels
dy, dx = np.gradient(out_image[0])
slope = np.sqrt(dx**2 + dy**2)

# 2. Filter for flat ground! 
# We'll consider a very low slope threshold to be "flat and buildable"
# '1' means flat, '0' means too steep
flat_ground = np.where(slope < 0.5, 1, 0)

# 3. Map Algebra: Combine both maps to find the exact Relocation Zones
# We multiply the two layers. 1 * 1 = 1 (Safe & Flat). 
# If it's low ground (0) or steep ground (0), it gets multiplied out to 0.
safe_and_flat = safe_elevation[0] * flat_ground

# 4. Plot the final Relocation Zone map!
fig, ax = plt.subplots(figsize=(10, 10))
# Let's plot this one in a nice dark blue to stand out
plt.imshow(safe_and_flat, cmap='Blues')
plt.title("Optimal Relocation Zones (High > 10ft AND Flat)")
plt.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Download the neighborhood boundaries (Census Tracts) for Florida directly from the government
print("Downloading Census Tract boundaries...")
tracts = gpd.read_file("https://www2.census.gov/geo/tiger/TIGER2020/TRACT/tl_2020_12_tract.zip")

# Filter for just Miami-Dade County (County code '086')
miami_tracts = tracts[tracts['COUNTYFP'] == '086']

# 2. Rip the 2020 Total Population numbers straight from the US Census API
print("Pulling population data from the Census API...")
url = "https://api.census.gov/data/2020/dec/pl?get=P1_001N&for=tract:*&in=state:12&in=county:086"
pop_data = pd.read_json(url)

# Clean up the API data table so it's readable
pop_data.columns = pop_data.iloc[0]
pop_data = pop_data[1:]
pop_data = pop_data.rename(columns={'P1_001N': 'Population'})
pop_data['Population'] = pop_data['Population'].astype(int)

# 3. Glue the population numbers to the map boundaries!
miami_pop_map = miami_tracts.merge(pop_data, left_on='TRACTCE', right_on='tract')

# 4. Plot a population heatmap to prove it worked
fig, ax = plt.subplots(figsize=(10, 10))
miami_pop_map.plot(column='Population', cmap='OrRd', legend=True, ax=ax, edgecolor='black', linewidth=0.2)
plt.title("Miami-Dade 2020 Population by Census Tract")
plt.show()
# Out:
# ...
# Pulling population data from the Census API...

# %%
import warnings
warnings.filterwarnings('ignore') # Hides annoying math warnings

# 1. To calculate area accurately, we project both maps to Web Mercator (meters instead of degrees)
miami_pop_map = miami_pop_map.to_crs(epsg=3857)
miami_flood = miami_flood.to_crs(epsg=3857)

# --- THE FIX: Repair invalid geometries to stop the code from freezing ---
miami_pop_map.geometry = miami_pop_map.geometry.make_valid()
miami_flood.geometry = miami_flood.geometry.make_valid()

# 2. Calculate the original total area of every single neighborhood
miami_pop_map['orig_area'] = miami_pop_map.geometry.area

# 3. THE INTERSECT! Smash the flood map into the population map
flooded_tracts = gpd.overlay(miami_pop_map, miami_flood, how='intersection')

# 4. Calculate the area of the water that is specifically inside each neighborhood
flooded_tracts['flood_area'] = flooded_tracts.geometry.area

# 5. Math time: Calculate the percentage flooded, then multiply by the population
flooded_tracts['pct_flooded'] = flooded_tracts['flood_area'] / flooded_tracts['orig_area']
flooded_tracts['displaced_people'] = flooded_tracts['Population'] * flooded_tracts['pct_flooded']

# 6. Add it all up to get your final disaster metric!
total_displaced = int(flooded_tracts['displaced_people'].sum())

print(f"🔥 FINAL ANALYSIS RESULT 🔥")
print(f"A 1-foot sea level rise in Miami-Dade County will permanently displace approximately {total_displaced:,} people.")

# 7. Plot the true impact map
fig, ax = plt.subplots(figsize=(10, 10))
miami_pop_map.plot(ax=ax, color='lightgrey', edgecolor='white', linewidth=0.5)
flooded_tracts.plot(column='displaced_people', cmap='Reds', legend=True, ax=ax)
plt.title("Impact Zones: Displaced Population Under 1-Foot Sea Level Rise")
plt.show()

# %%
# --- EXPANSION 1: TOTAL LAND LOSS CALCULATION ---
# Calculates the total physical land area lost to a 1-ft SLR

total_flooded_sq_meters = flooded_tracts.geometry.area.sum()
total_flooded_sq_miles = total_flooded_sq_meters / 2.59e+6

print(f"CRITICAL METRIC: Total Land Area Lost to 1-ft SLR: {round(total_flooded_sq_miles, 2)} square miles")

# %%
# --- EXPANSION 2: DISPLACEMENT SEVERITY CHOROPLETH ---
# Generates a heatmap of the displaced population by Census Tract

import matplotlib.subplots as plt

fig, ax = plt.subplots(figsize=(12, 12))

# Plot the base county
miami.plot(ax=ax, color='lightgrey', edgecolor='white', linewidth=0.5)

# Plot the flooded tracts, coloring by displaced population severity
flooded_tracts.plot(column='displaced_population_column', # Ensure this matches your variable name
                    ax=ax, 
                    cmap='OrRd', 
                    legend=True,
                    legend_kwds={'label': "Displaced Individuals per Tract",
                                 'orientation': "horizontal",
                                 'shrink': 0.6})

ax.set_title('Displacement Severity Heatmap', fontsize=16, fontweight='bold')
plt.axis('off')

plt.savefig('Displacement_Heatmap.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
# ==============================================================================
# PHASE 1: LIBRARIES & COUNTY BASELINE
# ==============================================================================
import os
import glob
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import rasterio
from rasterio.merge import merge
from rasterio.mask import mask
import warnings
warnings.filterwarnings('ignore') # Hides annoying math warnings

# 1. Load the US Counties map
counties = gpd.read_file("tl_2023_us_county.shp")

# 2. Filter for Miami-Dade County
miami = counties[(counties['NAME'] == 'Miami-Dade') & (counties['STATEFP'] == '12')]


# ==============================================================================
# PHASE 2: ELEVATION RASTER MERGING & CLIPPING
# ==============================================================================
# 1. Find all USGS tif files (ignoring old corrupted merged ones)
tif_files = glob.glob("*.tif") + glob.glob("*.TIF") + glob.glob("data/*.tif") + glob.glob("data/*.TIF")
tif_files = [f for f in tif_files if "merged" not in f.lower()]

# 2. Stitch them together safely
src_files_to_mosaic = []
for fp in set(tif_files): 
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

mosaic, out_trans = merge(src_files_to_mosaic)
out_meta = src_files_to_mosaic[0].meta.copy()
out_meta.update({
    "driver": "GTiff",
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": out_trans
})

with rasterio.open("miami_merged_elevation_FIXED.tif", "w", **out_meta) as dest:
    dest.write(mosaic)

for src in src_files_to_mosaic:
    src.close()

# 3. Open the stitched map and clip it to Miami-Dade
with rasterio.open("miami_merged_elevation_FIXED.tif") as src:
    miami_projected = miami.to_crs(src.crs)
    out_image, out_transform = mask(src, miami_projected.geometry, crop=True)


# ==============================================================================
# PHASE 3: TOPOGRAPHIC MAP ALGEBRA
# ==============================================================================
# 1. Safe Elevation (> 3 meters)
safe_elevation = np.where(out_image > 3, 1, 0)

# 2. Flat Ground (slope < 0.5)
dy, dx = np.gradient(out_image[0])
slope = np.sqrt(dx**2 + dy**2)
flat_ground = np.where(slope < 0.5, 1, 0)

# 3. Combine: Safe AND Flat
safe_and_flat = safe_elevation[0] * flat_ground


# ==============================================================================
# PHASE 4: DEMOGRAPHIC IMPACT & DISPLACEMENT
# ==============================================================================
# NOTE: Ensure you have loaded your miami_pop_map and miami_flood variables before this runs!
miami_pop_map = gpd.read_file("YOUR_CENSUS_TRACTS.shp") 
miami_flood = gpd.read_file("YOUR_NOAA_FLOOD.shp")

# 1. Project to Web Mercator for accurate area calculation (meters)
miami_pop_map = miami_pop_map.to_crs(epsg=3857)
miami_flood = miami_flood.to_crs(epsg=3857)

# 2. CRITICAL FIX: Repair invalid geometries to stop the code from freezing
miami_pop_map.geometry = miami_pop_map.geometry.make_valid()
miami_flood.geometry = miami_flood.geometry.make_valid()

# 3. Calculate original area
miami_pop_map['orig_area'] = miami_pop_map.geometry.area

# 4. Spatial Intersection
flooded_tracts = gpd.overlay(miami_pop_map, miami_flood, how='intersection')

# 5. Calculate displacement math
flooded_tracts['flood_area'] = flooded_tracts.geometry.area
flooded_tracts['pct_flooded'] = flooded_tracts['flood_area'] / flooded_tracts['orig_area']
flooded_tracts['displaced_people'] = flooded_tracts['Population'] * flooded_tracts['pct_flooded']

total_displaced = int(flooded_tracts['displaced_people'].sum())

# 6. Calculate total physical land lost
total_flooded_sq_meters = flooded_tracts.geometry.area.sum()
total_flooded_sq_miles = total_flooded_sq_meters / 2.59e+6

print("🔥 FINAL ANALYSIS RESULT 🔥")
print(f"Total Land Area Lost: {round(total_flooded_sq_miles, 2)} square miles")
print(f"Total People Displaced: {total_displaced:,}")


# ==============================================================================
# PHASE 5: FINAL VISUALIZATIONS
# ==============================================================================
# Plot 1: The Safe Zones
fig, ax1 = plt.subplots(figsize=(8, 8))
ax1.imshow(safe_and_flat, cmap='Blues')
ax1.set_title("Optimal Relocation Zones (High > 10ft AND Flat)")
ax1.axis('off')
plt.show()

# Plot 2: Displacement Heatmap
fig, ax2 = plt.subplots(figsize=(10, 10))
miami_pop_map.plot(ax=ax2, color='lightgrey', edgecolor='white', linewidth=0.5)
flooded_tracts.plot(column='displaced_people', cmap='OrRd', legend=True, ax=ax2,
                    legend_kwds={'label': "Displaced Individuals per Tract",
                                 'orientation': "horizontal",
                                 'shrink': 0.6})
ax2.set_title("Displacement Severity Heatmap", fontsize=16, fontweight='bold')
ax2.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[11], line 75
#      68 safe_and_flat = safe_elevation[0] * flat_ground
#      71 # ==============================================================================
#      72 # PHASE 4: DEMOGRAPHIC IMPACT & DISPLACEMENT
#      73 # ==============================================================================
#      74 # NOTE: Ensure you have loaded your miami_pop_map and miami_flood variables before this runs!
# ---> 75 miami_pop_map = gpd.read_file("YOUR_CENSUS_TRACTS.shp")
#      76 miami_flood = gpd.read_file("YOUR_NOAA_FLOOD.shp")
#      78 # 1. Project to Web Mercator for accurate area calculation (meters)
#
# File ~/.local/lib/python3.10/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
# ...

# %%
# The error "DataSourceError: YOUR_CENSUS_TRACTS.shp: No such file or directory" 
# occurred because the placeholder text was not replaced with your actual file names.
# You must insert the exact names of your downloaded shapefiles in Phase 4 before running.

# ==============================================================================
# PHASE 1: LIBRARIES & COUNTY BASELINE
# ==============================================================================
import os
import glob
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import rasterio
from rasterio.merge import merge
from rasterio.mask import mask
import warnings
warnings.filterwarnings('ignore')

# 1. Load the US Counties map
counties = gpd.read_file("tl_2023_us_county.shp")

# 2. Filter for Miami-Dade County
miami = counties[(counties['NAME'] == 'Miami-Dade') & (counties['STATEFP'] == '12')]

# ==============================================================================
# PHASE 2: ELEVATION RASTER MERGING & CLIPPING
# ==============================================================================
# 1. Find all USGS tif files (ignoring old corrupted merged ones)
tif_files = glob.glob("*.tif") + glob.glob("*.TIF") + glob.glob("data/*.tif") + glob.glob("data/*.TIF")
tif_files = [f for f in tif_files if "merged" not in f.lower()]

# 2. Stitch them together safely
src_files_to_mosaic = []
for fp in set(tif_files): 
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

mosaic, out_trans = merge(src_files_to_mosaic)
out_meta = src_files_to_mosaic[0].meta.copy()
out_meta.update({
    "driver": "GTiff",
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": out_trans
})

with rasterio.open("miami_merged_elevation_FIXED.tif", "w", **out_meta) as dest:
    dest.write(mosaic)

for src in src_files_to_mosaic:
    src.close()

# 3. Open the stitched map and clip it to Miami-Dade
with rasterio.open("miami_merged_elevation_FIXED.tif") as src:
    miami_projected = miami.to_crs(src.crs)
    out_image, out_transform = mask(src, miami_projected.geometry, crop=True)

# ==============================================================================
# PHASE 3: TOPOGRAPHIC MAP ALGEBRA
# ==============================================================================
# 1. Safe Elevation (> 3 meters)
safe_elevation = np.where(out_image > 3, 1, 0)

# 2. Flat Ground (slope < 0.5)
dy, dx = np.gradient(out_image[0])
slope = np.sqrt(dx**2 + dy**2)
flat_ground = np.where(slope < 0.5, 1, 0)

# 3. Combine: Safe AND Flat
safe_and_flat = safe_elevation[0] * flat_ground

# ==============================================================================
# PHASE 4: DEMOGRAPHIC IMPACT & DISPLACEMENT
# ==============================================================================
# CRITICAL: REPLACE THESE TWO STRINGS WITH YOUR ACTUAL FILE NAMES
census_shapefile_name = "INSERT_YOUR_CENSUS_FILE_NAME_HERE.shp"
flood_shapefile_name = "INSERT_YOUR_NOAA_FLOOD_FILE_NAME_HERE.shp"

miami_pop_map = gpd.read_file(census_shapefile_name) 
miami_flood = gpd.read_file(flood_shapefile_name)

# 1. Project to Web Mercator for accurate area calculation (meters)
miami_pop_map = miami_pop_map.to_crs(epsg=3857)
miami_flood = miami_flood.to_crs(epsg=3857)

# 2. Repair invalid geometries to stop the code from freezing
miami_pop_map.geometry = miami_pop_map.geometry.make_valid()
miami_flood.geometry = miami_flood.geometry.make_valid()

# 3. Calculate original area
miami_pop_map['orig_area'] = miami_pop_map.geometry.area

# 4. Spatial Intersection
flooded_tracts = gpd.overlay(miami_pop_map, miami_flood, how='intersection')

# 5. Calculate displacement math
flooded_tracts['flood_area'] = flooded_tracts.geometry.area
flooded_tracts['pct_flooded'] = flooded_tracts['flood_area'] / flooded_tracts['orig_area']
flooded_tracts['displaced_people'] = flooded_tracts['Population'] * flooded_tracts['pct_flooded']

total_displaced = int(flooded_tracts['displaced_people'].sum())

# 6. Calculate total physical land lost
total_flooded_sq_meters = flooded_tracts.geometry.area.sum()
total_flooded_sq_miles = total_flooded_sq_meters / 2.59e+6

print("🔥 FINAL ANALYSIS RESULT 🔥")
print(f"Total Land Area Lost: {round(total_flooded_sq_miles, 2)} square miles")
print(f"Total People Displaced: {total_displaced:,}")

# ==============================================================================
# PHASE 5: FINAL VISUALIZATIONS
# ==============================================================================
# Plot 1: The Safe Zones
fig, ax1 = plt.subplots(figsize=(8, 8))
ax1.imshow(safe_and_flat, cmap='Blues')
ax1.set_title("Optimal Relocation Zones (High > 10ft AND Flat)")
ax1.axis('off')
plt.show()

# Plot 2: Displacement Heatmap
fig, ax2 = plt.subplots(figsize=(10, 10))
miami_pop_map.plot(ax=ax2, color='lightgrey', edgecolor='white', linewidth=0.5)
flooded_tracts.plot(column='displaced_people', cmap='OrRd', legend=True, ax=ax2,
                    legend_kwds={'label': "Displaced Individuals per Tract",
                                 'orientation': "horizontal",
                                 'shrink': 0.6})
ax2.set_title("Displacement Severity Heatmap", fontsize=16, fontweight='bold')
ax2.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[12], line 79
#      76 census_shapefile_name = "INSERT_YOUR_CENSUS_FILE_NAME_HERE.shp"
#      77 flood_shapefile_name = "INSERT_YOUR_NOAA_FLOOD_FILE_NAME_HERE.shp"
# ---> 79 miami_pop_map = gpd.read_file(census_shapefile_name)
#      80 miami_flood = gpd.read_file(flood_shapefile_name)
#      82 # 1. Project to Web Mercator for accurate area calculation (meters)
#
# File ~/.local/lib/python3.10/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# ...
